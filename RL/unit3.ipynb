# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚
#
# If you see `ERROR: pip's dependency resolver does not currently take into account all the packages that are installed.` **this is normal and it's not a critical error** there's a conflict of version. But the packages we need are installed.

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Looking in indexes: https://mirrors.ustc.edu.cn/pypi/simple, https://pypi.org/simple
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-vwpyuahw
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-vwpyuahw
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit cd701a094ac5120f1795c747fd4c490aa79f94e6
#   Running command git submodule update --init --recursive -q
# ERROR: Operation cancelled by user
# ^C

# %%
# !apt-get install swig cmake ffmpeg

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Looking in indexes: https://mirrors.ustc.edu.cn/pypi/simple, https://pypi.org/simple
# Requirement already satisfied: gymnasium[atari] in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[atari]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[atari]) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[atari]) (0.0.4)
# Collecting ale_py>=0.9 (from gymnasium[atari])
#   Downloading ale_py-0.11.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (9.0 kB)
# Downloading ale_py-0.11.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 192.8 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: ale_py
# Successfully installed ale_py-0.11.1
# Looking in indexes: https://mirrors.ustc.edu.cn/pypi/simple, https://pypi.org/simple
# Requirement already satisfied: gymnasium[accept-rom-license] in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (1.1.1)
# WARNING: gymnasium 1.1.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/rhs/miniconda3/envs/RL/lib/python3.10/site-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 2849297770
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.11.1+2750686)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs//dqn/SpaceInvadersNoFrameskip-v4_3
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 305      |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 971      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 925      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.91e+03 |
# |    ep_rew_mean      | 250      |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1021     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1039     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1045     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1051     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 3153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1061     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1066     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1069     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4976     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1072     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1077     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1078     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1079     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 7712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1084     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 8746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1085     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 9430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1085     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 9980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1087     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 10686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1088     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11367    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1088     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 11998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1089     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 12558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1089     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 13204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1089     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 13636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1091     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1093     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 15804    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1092     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 16229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1093     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 17027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1094     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 17629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1093     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 18334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1094     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 19190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1094     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 19803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.798    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1094     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 20441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1094     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 21081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1095     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 21777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1094     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 22289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1094     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 23032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1095     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 23715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1095     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 24153    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1095     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 24868    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=177.00 +/- 59.80
# Episode length: 2421.80 +/- 309.15
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.42e+03 |
# |    mean_reward      | 177      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 957      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 25587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 961      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 26366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 963      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 26910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 965      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 27332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 966      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 27674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 971      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 28793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 973      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 29381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.703    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 975      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 29961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 979      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 30862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 981      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 31419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.684    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 982      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 31957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 986      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 32852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 989      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 33776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.658    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 991      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 34588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 993      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 35286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 994      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 35839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 996      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 36439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.633    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 997      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 37068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.622    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1000     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 38166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.616    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1002     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 38810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1003     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 39458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1004     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 39942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.597    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1006     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 40686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1006     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 41121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1008     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 41854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1011     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 42962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1012     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 43621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1013     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 44204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1014     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 44811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1016     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 45785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1017     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 46428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1018     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 46982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1019     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 47734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1021     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 48554    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1021     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 49071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1023     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 49988    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=239.00 +/- 102.59
# Episode length: 2567.40 +/- 170.07
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.57e+03 |
# |    mean_reward      | 239      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.499    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 952      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 50617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.493    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 953      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 51203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 955      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 51853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.48     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 956      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 52478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 957      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 52847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 958      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 53467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.464    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 960      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 54134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 961      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 54583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 962      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 55166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 963      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 55680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 964      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 56030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.438    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 966      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 56806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 967      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 57657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 969      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 58388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 971      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 59244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.403    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 973      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 60257    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 974      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 60668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.394    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 975      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 61222    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 975      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 61615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.386    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 976      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 61997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.379    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 977      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 62678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 979      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 63583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.365    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 980      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 64145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 981      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 64726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 982      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 65286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.343    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 983      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 66343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 984      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 66978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 985      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 67532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.324    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 986      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 68311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 988      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 69429    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.308    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 989      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 69942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 990      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 70490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.298    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 990      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 70949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 991      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 71469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 991      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 71940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 992      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 72458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 993      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 73031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 994      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 73803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 995      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 74737    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=231.00 +/- 53.05
# Episode length: 2768.60 +/- 328.31
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.77e+03 |
# |    mean_reward      | 231      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 941      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 75361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 942      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 76337    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.239    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 943      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 76873    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 945      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 77632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 946      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 78308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 948      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 79283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.209    |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 213490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 379      |
# |    time_elapsed     | 2521     |
# |    total_timesteps  | 956216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00973  |
# |    n_updates        | 214053   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 379      |
# |    time_elapsed     | 2524     |
# |    total_timesteps  | 957455   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 214363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 379      |
# |    time_elapsed     | 2529     |
# |    total_timesteps  | 959525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0147   |
# |    n_updates        | 214881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 379      |
# |    time_elapsed     | 2534     |
# |    total_timesteps  | 961332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 215332   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 379      |
# |    time_elapsed     | 2537     |
# |    total_timesteps  | 962601   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 215650   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 599      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 379      |
# |    time_elapsed     | 2540     |
# |    total_timesteps  | 963819   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 215954   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 379      |
# |    time_elapsed     | 2544     |
# |    total_timesteps  | 965499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 216374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 379      |
# |    time_elapsed     | 2549     |
# |    total_timesteps  | 967158   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 216789   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 379      |
# |    time_elapsed     | 2553     |
# |    total_timesteps  | 968692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 217172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 379      |
# |    time_elapsed     | 2558     |
# |    total_timesteps  | 970647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00897  |
# |    n_updates        | 217661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 379      |
# |    time_elapsed     | 2563     |
# |    total_timesteps  | 972517   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 218129   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 379      |
# |    time_elapsed     | 2566     |
# |    total_timesteps  | 973870   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 218467   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=571.00 +/- 198.13
# Episode length: 4034.00 +/- 1239.44
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.03e+03 |
# |    mean_reward      | 571      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 378      |
# |    time_elapsed     | 2577     |
# |    total_timesteps  | 975387   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00901  |
# |    n_updates        | 218846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 378      |
# |    time_elapsed     | 2581     |
# |    total_timesteps  | 977077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0139   |
# |    n_updates        | 219269   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 378      |
# |    time_elapsed     | 2584     |
# |    total_timesteps  | 978261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0374   |
# |    n_updates        | 219565   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 378      |
# |    time_elapsed     | 2588     |
# |    total_timesteps  | 979566   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0218   |
# |    n_updates        | 219891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 378      |
# |    time_elapsed     | 2592     |
# |    total_timesteps  | 981387   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00931  |
# |    n_updates        | 220346   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 378      |
# |    time_elapsed     | 2597     |
# |    total_timesteps  | 983051   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 220762   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 378      |
# |    time_elapsed     | 2599     |
# |    total_timesteps  | 984116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0958   |
# |    n_updates        | 221028   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 378      |
# |    time_elapsed     | 2605     |
# |    total_timesteps  | 986191   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 221547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 603      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3940     |
# |    fps              | 378      |
# |    time_elapsed     | 2609     |
# |    total_timesteps  | 987829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 221957   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.1e+03  |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3944     |
# |    fps              | 378      |
# |    time_elapsed     | 2612     |
# |    total_timesteps  | 989068   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 222266   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3948     |
# |    fps              | 378      |
# |    time_elapsed     | 2616     |
# |    total_timesteps  | 990759   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 222689   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3952     |
# |    fps              | 378      |
# |    time_elapsed     | 2621     |
# |    total_timesteps  | 992483   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 223120   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.04e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3956     |
# |    fps              | 378      |
# |    time_elapsed     | 2627     |
# |    total_timesteps  | 994933   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 223733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3960     |
# |    fps              | 378      |
# |    time_elapsed     | 2631     |
# |    total_timesteps  | 996523   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00992  |
# |    n_updates        | 224130   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 601      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3964     |
# |    fps              | 378      |
# |    time_elapsed     | 2634     |
# |    total_timesteps  | 997611   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 224402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 602      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3968     |
# |    fps              | 378      |
# |    time_elapsed     | 2639     |
# |    total_timesteps  | 999493   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 224873   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=573.00 +/- 133.85
# Episode length: 3606.00 +/- 404.42
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.61e+03 |
# |    mean_reward      | 573      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_3

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps _________  --folder logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name _____________________ -orga _____________________ -f logs/

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# ###.

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
